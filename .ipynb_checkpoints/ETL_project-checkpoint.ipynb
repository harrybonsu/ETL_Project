# %%
# Dependencies

import requests
from config import api_key
import pandas as pd
import datetime as dt
from datetime import datetime as ds
import json
from pprint import pprint
import sqlalchemy
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %% [markdown]
# ### Getting Inflation data for US by reading HTML

# %%
# Define the url to read the html

url = 'https://www.in2013dollars.com/us/inflation/1930?amount=1'

# %%
# Read the web page and print results

cpi_inflation = pd.read_html(url)
cpi_inflation
# Out:
# [                            0               1
#  0     Cumulative price change       1,534.75%
#  1      Average inflation rate           3.12%
#  2  Converted amount ($1 base)          $16.35
#  3  Price difference ($1 base)          $15.35
#  4                 CPI in 1930          16.700
#  5                 CPI in 2021         273.003
#  6           Inflation in 1930          -2.34%
#  7           Inflation in 2021           5.37%
#  8                  $1 in 1930  $16.35 in 2021,
#      Year Dollar Value Inflation Rate
#  0   1930        $1.00         -2.34%
#  1   1931        $0.91         -8.98%
#  2   1932        $0.82         -9.87%
#  3   1933        $0.78         -5.11%
#  4   1934        $0.80          3.08%
#  ..   ...          ...            ...
#  87  2017       $14.68          2.13%
#  88  2018       $15.04          2.49%
#  89  2019       $15.31          1.76%
#  90  2020       $15.50          1.23%
#  91  2021       $16.35         5.48%*
#
#  [92 rows x 3 columns],
#                   Initial value              Equivalent value
#  0            $1 dollar in 1930          $16.35 dollars today
#  1           $5 dollars in 1930          $81.74 dollars today
#  2          $10 dollars in 1930         $163.47 dollars today
#  3          $50 dollars in 1930         $817.37 dollars today
#  4         $100 dollars in 1930       $1,634.75 dollars today
#  5         $500 dollars in 1930       $8,173.74 dollars today
#  6       $1,000 dollars in 1930      $16,347.49 dollars today
#  7       $5,000 dollars in 1930      $81,737.43 dollars today
#  8      $10,000 dollars in 1930     $163,474.85 dollars today
#  9      $50,000 dollars in 1930     $817,374.25 dollars today
#  10    $100,000 dollars in 1930   $1,634,748.50 dollars today
#  11    $500,000 dollars in 1930   $8,173,742.51 dollars today
#  12  $1,000,000 dollars in 1930  $16,347,485.03 dollars today,
#                        Category  Avg Inflation (%)  Total Inflation (%)  \
#  0           Food and beverages               3.88              3082.64
#  1                      Housing               4.16              3964.65
#  2                      Apparel               1.78               398.34
#  3               Transportation               3.25              1742.00
#  4                 Medical care               4.69              6357.14
#  5                   Recreation               1.12               175.01
#  6  Education and communication               1.82               418.29
#  7     Other goods and services               4.93              7908.16
#
#     $1 in 1930 → 2021
#  0              31.83
#  1              40.65
#  2               4.98
#  3              18.42
#  4              64.57
#  5               2.75
#  6               5.18
#  7              80.08  ,
#                 Unnamed: 0 Original Amount Final Amount       Change
#  0                 Nominal              $1    $5,064.60  506,360.18%
#  1  RealInflation Adjusted              $1      $309.81   30,880.92%,
#                              0               1
#  0     Cumulative price change       1,534.75%
#  1      Average inflation rate           3.12%
#  2  Converted amount ($1 base)          $16.35
#  3  Price difference ($1 base)          $15.35
#  4                 CPI in 1930          16.700
#  5                 CPI in 2021         273.003
#  6           Inflation in 1930          -2.34%
#  7           Inflation in 2021           5.37%
#  8                  $1 in 1930  $16.35 in 2021]

# %%
# Select the required table for CPI and Inflation from the page and build the required dataframe

cpi_inflation_df = cpi_inflation[1]
cpi_inflation_df
# Out:
#     Year Dollar Value Inflation Rate
# 0   1930        $1.00         -2.34%
# 1   1931        $0.91         -8.98%
# 2   1932        $0.82         -9.87%
# 3   1933        $0.78         -5.11%
# 4   1934        $0.80          3.08%
# ..   ...          ...            ...
# 87  2017       $14.68          2.13%
# 88  2018       $15.04          2.49%
# 89  2019       $15.31          1.76%
# 90  2020       $15.50          1.23%
# 91  2021       $16.35         5.48%*
#
# [92 rows x 3 columns]

# %%
# Rename Columns

cpi_inflation_df.columns = ['date', 'dollar_value', 'inflation_rate']
cpi_inflation_df
# Out:
#     date dollar_value inflation_rate
# 0   1930        $1.00         -2.34%
# 1   1931        $0.91         -8.98%
# 2   1932        $0.82         -9.87%
# 3   1933        $0.78         -5.11%
# 4   1934        $0.80          3.08%
# ..   ...          ...            ...
# 87  2017       $14.68          2.13%
# 88  2018       $15.04          2.49%
# 89  2019       $15.31          1.76%
# 90  2020       $15.50          1.23%
# 91  2021       $16.35         5.48%*
#
# [92 rows x 3 columns]

# %% [markdown]
# ### Getting GDP data from St. Louis Fed. using an API call

# %%
#https://alfred.stlouisfed.org/series/downloaddata?seid=MABMM301USA657S

url = 'https://api.stlouisfed.org/fred/series/observations?series_id=A191RL1A225NBEA'
realtime_start = '1958-01-01'
realtime_end = '2021-01-31'

# %%
# Build query URL

query_url = url + "&realtime_start=" + realtime_start + "&realtime_end=" + realtime_end + "&api_key=" + api_key + "&file_type=json"

# %%
# Print the results of the query in a json format

response = requests.get(query_url).json()
pprint(response)
# Out:
# {'count': 129,
#  'file_type': 'json',
#  'limit': 100000,
#  'observation_end': '9999-12-31',
#  'observation_start': '1600-01-01',
#  'observations': [{'date': '1930-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-8.5'},
#                   {'date': '1931-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-6.4'},
#                   {'date': '1932-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-12.9'},
#                   {'date': '1933-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '-1.3'},
#                   {'date': '1933-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '-1.2'},
#                   {'date': '1934-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '10.8'},
#                   {'date': '1935-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '8.9'},
#                   {'date': '1936-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '12.9'},
#                   {'date': '1937-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '5.1'},
#                   {'date': '1938-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-3.3'},
#                   {'date': '1939-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '8'},
#                   {'date': '1940-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '8.8'},
#                   {'date': '1941-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '17.7'},
#                   {'date': '1942-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '18.9'},
#                   {'date': '1943-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '17'},
#                   {'date': '1944-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '8'},
#                   {'date': '1945-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-1'},
#                   {'date': '1946-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-11.6'},
#                   {'date': '1947-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-1.1'},
#                   {'date': '1948-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.1'},
#                   {'date': '1949-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.5'},
#                   {'date': '1949-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '-0.6'},
#                   {'date': '1950-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '8.7'},
#                   {'date': '1951-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '8.1'},
#                   {'date': '1951-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '8.0'},
#                   {'date': '1952-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.1'},
#                   {'date': '1953-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.7'},
#                   {'date': '1954-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.6'},
#                   {'date': '1955-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '7.1'},
#                   {'date': '1956-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.1'},
#                   {'date': '1957-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.1'},
#                   {'date': '1958-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.7'},
#                   {'date': '1959-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '6.9'},
#                   {'date': '1960-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.6'},
#                   {'date': '1961-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.6'},
#                   {'date': '1962-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '6.1'},
#                   {'date': '1963-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.4'},
#                   {'date': '1964-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '5.8'},
#                   {'date': '1965-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '6.5'},
#                   {'date': '1966-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '6.6'},
#                   {'date': '1967-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.7'},
#                   {'date': '1968-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.9'},
#                   {'date': '1969-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.1'},
#                   {'date': '1970-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '0.2'},
#                   {'date': '1971-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.3'},
#                   {'date': '1972-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '5.2'},
#                   {'date': '1972-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '5.3'},
#                   {'date': '1973-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '5.6'},
#                   {'date': '1974-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.5'},
#                   {'date': '1975-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.2'},
#                   {'date': '1976-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '5.4'},
#                   {'date': '1977-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.6'},
#                   {'date': '1978-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '5.6'},
#                   {'date': '1978-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '5.5'},
#                   {'date': '1979-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.2'},
#                   {'date': '1980-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.2'},
#                   {'date': '1980-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '-0.3'},
#                   {'date': '1981-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.6'},
#                   {'date': '1981-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.5'},
#                   {'date': '1982-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '-1.9'},
#                   {'date': '1982-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '-1.8'},
#                   {'date': '1983-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.6'},
#                   {'date': '1984-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '7.3'},
#                   {'date': '1984-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '7.2'},
#                   {'date': '1985-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.2'},
#                   {'date': '1986-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.5'},
#                   {'date': '1987-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.5'},
#                   {'date': '1988-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.2'},
#                   {'date': '1989-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.7'},
#                   {'date': '1990-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '1.9'},
#                   {'date': '1991-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.1'},
#                   {'date': '1992-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.6'},
#                   {'date': '1992-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '3.5'},
#                   {'date': '1993-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.7'},
#                   {'date': '1993-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.8'},
#                   {'date': '1994-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4'},
#                   {'date': '1995-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.7'},
#                   {'date': '1996-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.8'},
#                   {'date': '1997-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.5'},
#                   {'date': '1997-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '4.4'},
#                   {'date': '1998-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.5'},
#                   {'date': '1999-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.7'},
#                   {'date': '1999-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '4.8'},
#                   {'date': '2000-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '4.1'},
#                   {'date': '2001-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '1'},
#                   {'date': '2002-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '1.8'},
#                   {'date': '2002-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '1.7'},
#                   {'date': '2003-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.8'},
#                   {'date': '2003-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.9'},
#                   {'date': '2004-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.8'},
#                   {'date': '2005-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '3.3'},
#                   {'date': '2005-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '3.5'},
#                   {'date': '2006-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.7'},
#                   {'date': '2006-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.9'},
#                   {'date': '2007-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '1.8'},
#                   {'date': '2007-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '1.9'},
#                   {'date': '2008-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '-0.3'},
#                   {'date': '2008-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '-0.1'},
#                   {'date': '2009-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '-2.8'},
#                   {'date': '2009-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '-2.5'},
#                   {'date': '2010-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.5'},
#                   {'date': '2010-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.6'},
#                   {'date': '2011-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2014-10-31',
#                    'value': '1.6'},
#                   {'date': '2012-01-01',
#                    'realtime_end': '2015-07-29',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.3'},
#                   {'date': '2012-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2015-07-30',
#                    'value': '2.2'},
#                   {'date': '2013-01-01',
#                    'realtime_end': '2015-07-29',
#                    'realtime_start': '2014-10-31',
#                    'value': '2.2'},
#                   {'date': '2013-01-01',
#                    'realtime_end': '2016-07-28',
#                    'realtime_start': '2015-07-30',
#                    'value': '1.5'},
#                   {'date': '2013-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2016-07-29',
#                    'value': '1.7'},
#                   {'date': '2013-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '1.8'},
#                   {'date': '2014-01-01',
#                    'realtime_end': '2017-07-27',
#                    'realtime_start': '2015-01-30',
#                    'value': '2.4'},
#                   {'date': '2014-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2017-07-28',
#                    'value': '2.6'},
#                   {'date': '2014-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.5'},
#                   {'date': '2015-01-01',
#                    'realtime_end': '2016-07-28',
#                    'realtime_start': '2016-01-29',
#                    'value': '2.4'},
#                   {'date': '2015-01-01',
#                    'realtime_end': '2017-07-27',
#                    'realtime_start': '2016-07-29',
#                    'value': '2.6'},
#                   {'date': '2015-01-01',
#                    'realtime_end': '2020-07-29',
#                    'realtime_start': '2017-07-28',
#                    'value': '2.9'},
#                   {'date': '2015-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2020-07-30',
#                    'value': '3.1'},
#                   {'date': '2016-01-01',
#                    'realtime_end': '2017-07-27',
#                    'realtime_start': '2017-01-27',
#                    'value': '1.6'},
#                   {'date': '2016-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2017-07-28',
#                    'value': '1.5'},
#                   {'date': '2016-01-01',
#                    'realtime_end': '2020-07-29',
#                    'realtime_start': '2018-07-27',
#                    'value': '1.6'},
#                   {'date': '2016-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2020-07-30',
#                    'value': '1.7'},
#                   {'date': '2017-01-01',
#                    'realtime_end': '2018-07-26',
#                    'realtime_start': '2018-01-26',
#                    'value': '2.3'},
#                   {'date': '2017-01-01',
#                    'realtime_end': '2019-07-25',
#                    'realtime_start': '2018-07-27',
#                    'value': '2.2'},
#                   {'date': '2017-01-01',
#                    'realtime_end': '2020-07-29',
#                    'realtime_start': '2019-07-26',
#                    'value': '2.4'},
#                   {'date': '2017-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2020-07-30',
#                    'value': '2.3'},
#                   {'date': '2018-01-01',
#                    'realtime_end': '2020-07-29',
#                    'realtime_start': '2019-02-28',
#                    'value': '2.9'},
#                   {'date': '2018-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2020-07-30',
#                    'value': '3.0'},
#                   {'date': '2019-01-01',
#                    'realtime_end': '2020-07-29',
#                    'realtime_start': '2020-01-30',
#                    'value': '2.3'},
#                   {'date': '2019-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2020-07-30',
#                    'value': '2.2'},
#                   {'date': '2020-01-01',
#                    'realtime_end': '2021-01-31',
#                    'realtime_start': '2021-01-28',
#                    'value': '-3.5'}],
#  'offset': 0,
#  'order_by': 'observation_date',
#  'output_type': 1,
#  'realtime_end': '2021-01-31',
#  'realtime_start': '1958-01-01',
#  'sort_order': 'asc',
#  'units': 'lin'}

# %%
# Select the observations from the response

pprint(response['observations'])
# Out:
# [{'date': '1930-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-8.5'},
#  {'date': '1931-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-6.4'},
#  {'date': '1932-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-12.9'},
#  {'date': '1933-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '-1.3'},
#  {'date': '1933-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '-1.2'},
#  {'date': '1934-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '10.8'},
#  {'date': '1935-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '8.9'},
#  {'date': '1936-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '12.9'},
#  {'date': '1937-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '5.1'},
#  {'date': '1938-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-3.3'},
#  {'date': '1939-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '8'},
#  {'date': '1940-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '8.8'},
#  {'date': '1941-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '17.7'},
#  {'date': '1942-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '18.9'},
#  {'date': '1943-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '17'},
#  {'date': '1944-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '8'},
#  {'date': '1945-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-1'},
#  {'date': '1946-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-11.6'},
#  {'date': '1947-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-1.1'},
#  {'date': '1948-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.1'},
#  {'date': '1949-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '-0.5'},
#  {'date': '1949-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '-0.6'},
#  {'date': '1950-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '8.7'},
#  {'date': '1951-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '8.1'},
#  {'date': '1951-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '8.0'},
#  {'date': '1952-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.1'},
#  {'date': '1953-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.7'},
#  {'date': '1954-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-0.6'},
#  {'date': '1955-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '7.1'},
#  {'date': '1956-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '2.1'},
#  {'date': '1957-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '2.1'},
#  {'date': '1958-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-0.7'},
#  {'date': '1959-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '6.9'},
#  {'date': '1960-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '2.6'},
#  {'date': '1961-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '2.6'},
#  {'date': '1962-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '6.1'},
#  {'date': '1963-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.4'},
#  {'date': '1964-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '5.8'},
#  {'date': '1965-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '6.5'},
#  {'date': '1966-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '6.6'},
#  {'date': '1967-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '2.7'},
#  {'date': '1968-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.9'},
#  {'date': '1969-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.1'},
#  {'date': '1970-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '0.2'},
#  {'date': '1971-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.3'},
#  {'date': '1972-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '5.2'},
#  {'date': '1972-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '5.3'},
#  {'date': '1973-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '5.6'},
#  {'date': '1974-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-0.5'},
#  {'date': '1975-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-0.2'},
#  {'date': '1976-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '5.4'},
#  {'date': '1977-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.6'},
#  {'date': '1978-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '5.6'},
#  {'date': '1978-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '5.5'},
#  {'date': '1979-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.2'},
#  {'date': '1980-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '-0.2'},
#  {'date': '1980-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '-0.3'},
#  {'date': '1981-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '2.6'},
#  {'date': '1981-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '2.5'},
#  {'date': '1982-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '-1.9'},
#  {'date': '1982-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '-1.8'},
#  {'date': '1983-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.6'},
#  {'date': '1984-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '7.3'},
#  {'date': '1984-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '7.2'},
#  {'date': '1985-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.2'},
#  {'date': '1986-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.5'},
#  {'date': '1987-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.5'},
#  {'date': '1988-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.2'},
#  {'date': '1989-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.7'},
#  {'date': '1990-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '1.9'},
#  {'date': '1991-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '-0.1'},
#  {'date': '1992-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '3.6'},
#  {'date': '1992-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '3.5'},
#  {'date': '1993-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '2.7'},
#  {'date': '1993-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '2.8'},
#  {'date': '1994-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4'},
#  {'date': '1995-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '2.7'},
#  {'date': '1996-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.8'},
#  {'date': '1997-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '4.5'},
#  {'date': '1997-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '4.4'},
#  {'date': '1998-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.5'},
#  {'date': '1999-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '4.7'},
#  {'date': '1999-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '4.8'},
#  {'date': '2000-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '4.1'},
#  {'date': '2001-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '1'},
#  {'date': '2002-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '1.8'},
#  {'date': '2002-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '1.7'},
#  {'date': '2003-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '2.8'},
#  {'date': '2003-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '2.9'},
#  {'date': '2004-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '3.8'},
#  {'date': '2005-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '3.3'},
#  {'date': '2005-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '3.5'},
#  {'date': '2006-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '2.7'},
#  {'date': '2006-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '2.9'},
#  {'date': '2007-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '1.8'},
#  {'date': '2007-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '1.9'},
#  {'date': '2008-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '-0.3'},
#  {'date': '2008-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '-0.1'},
#  {'date': '2009-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '-2.8'},
#  {'date': '2009-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '-2.5'},
#  {'date': '2010-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2014-10-31',
#   'value': '2.5'},
#  {'date': '2010-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '2.6'},
#  {'date': '2011-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2014-10-31',
#   'value': '1.6'},
#  {'date': '2012-01-01',
#   'realtime_end': '2015-07-29',
#   'realtime_start': '2014-10-31',
#   'value': '2.3'},
#  {'date': '2012-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2015-07-30',
#   'value': '2.2'},
#  {'date': '2013-01-01',
#   'realtime_end': '2015-07-29',
#   'realtime_start': '2014-10-31',
#   'value': '2.2'},
#  {'date': '2013-01-01',
#   'realtime_end': '2016-07-28',
#   'realtime_start': '2015-07-30',
#   'value': '1.5'},
#  {'date': '2013-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2016-07-29',
#   'value': '1.7'},
#  {'date': '2013-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '1.8'},
#  {'date': '2014-01-01',
#   'realtime_end': '2017-07-27',
#   'realtime_start': '2015-01-30',
#   'value': '2.4'},
#  {'date': '2014-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2017-07-28',
#   'value': '2.6'},
#  {'date': '2014-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2018-07-27',
#   'value': '2.5'},
#  {'date': '2015-01-01',
#   'realtime_end': '2016-07-28',
#   'realtime_start': '2016-01-29',
#   'value': '2.4'},
#  {'date': '2015-01-01',
#   'realtime_end': '2017-07-27',
#   'realtime_start': '2016-07-29',
#   'value': '2.6'},
#  {'date': '2015-01-01',
#   'realtime_end': '2020-07-29',
#   'realtime_start': '2017-07-28',
#   'value': '2.9'},
#  {'date': '2015-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2020-07-30',
#   'value': '3.1'},
#  {'date': '2016-01-01',
#   'realtime_end': '2017-07-27',
#   'realtime_start': '2017-01-27',
#   'value': '1.6'},
#  {'date': '2016-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2017-07-28',
#   'value': '1.5'},
#  {'date': '2016-01-01',
#   'realtime_end': '2020-07-29',
#   'realtime_start': '2018-07-27',
#   'value': '1.6'},
#  {'date': '2016-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2020-07-30',
#   'value': '1.7'},
#  {'date': '2017-01-01',
#   'realtime_end': '2018-07-26',
#   'realtime_start': '2018-01-26',
#   'value': '2.3'},
#  {'date': '2017-01-01',
#   'realtime_end': '2019-07-25',
#   'realtime_start': '2018-07-27',
#   'value': '2.2'},
#  {'date': '2017-01-01',
#   'realtime_end': '2020-07-29',
#   'realtime_start': '2019-07-26',
#   'value': '2.4'},
#  {'date': '2017-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2020-07-30',
#   'value': '2.3'},
#  {'date': '2018-01-01',
#   'realtime_end': '2020-07-29',
#   'realtime_start': '2019-02-28',
#   'value': '2.9'},
#  {'date': '2018-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2020-07-30',
#   'value': '3.0'},
#  {'date': '2019-01-01',
#   'realtime_end': '2020-07-29',
#   'realtime_start': '2020-01-30',
#   'value': '2.3'},
#  {'date': '2019-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2020-07-30',
#   'value': '2.2'},
#  {'date': '2020-01-01',
#   'realtime_end': '2021-01-31',
#   'realtime_start': '2021-01-28',
#   'value': '-3.5'}]

# %%
# Dump the results into pandas dataframe

gdp_df = pd.DataFrame(response['observations'])
gdp_df
# Out:
#     realtime_start realtime_end        date  value
# 0       2014-10-31   2021-01-31  1930-01-01   -8.5
# 1       2014-10-31   2021-01-31  1931-01-01   -6.4
# 2       2014-10-31   2021-01-31  1932-01-01  -12.9
# 3       2014-10-31   2018-07-26  1933-01-01   -1.3
# 4       2018-07-27   2021-01-31  1933-01-01   -1.2
# ..             ...          ...         ...    ...
# 124     2019-02-28   2020-07-29  2018-01-01    2.9
# 125     2020-07-30   2021-01-31  2018-01-01    3.0
# 126     2020-01-30   2020-07-29  2019-01-01    2.3
# 127     2020-07-30   2021-01-31  2019-01-01    2.2
# 128     2021-01-28   2021-01-31  2020-01-01   -3.5
#
# [129 rows x 4 columns]

# %%
# Select the required columns 'date' and 'value' for the analysis

gdp_df = gdp_df[['date', 'value']]
gdp_df
# Out:
#            date  value
# 0    1930-01-01   -8.5
# 1    1931-01-01   -6.4
# 2    1932-01-01  -12.9
# 3    1933-01-01   -1.3
# 4    1933-01-01   -1.2
# ..          ...    ...
# 124  2018-01-01    2.9
# 125  2018-01-01    3.0
# 126  2019-01-01    2.3
# 127  2019-01-01    2.2
# 128  2020-01-01   -3.5
#
# [129 rows x 2 columns]

# %%
# Rename Columns

gdp_df.columns = ['date', 'gdp_rate']
gdp_df
# Out:
#            date gdp_rate
# 0    1930-01-01     -8.5
# 1    1931-01-01     -6.4
# 2    1932-01-01    -12.9
# 3    1933-01-01     -1.3
# 4    1933-01-01     -1.2
# ..          ...      ...
# 124  2018-01-01      2.9
# 125  2018-01-01      3.0
# 126  2019-01-01      2.3
# 127  2019-01-01      2.2
# 128  2020-01-01     -3.5
#
# [129 rows x 2 columns]

# %%
# Change the dtype of the Year column from 'object' to 'datetime' to be able to select the year portion of date

gdp_df['date'] = [ds.strptime(x,'%Y-%m-%d') for x in gdp_df['date']]
# Out:
# <ipython-input-14-39d9e4b90d6e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_df['date'] = [ds.strptime(x,'%Y-%m-%d') for x in gdp_df['date']]

# %%
# Select just the years from the dates

gdp_df['date'] = gdp_df['date'].dt.year
gdp_df
# Out:
# <ipython-input-15-c729f58d5b78>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_df['date'] = gdp_df['date'].dt.year
#      date gdp_rate
# 0    1930     -8.5
# 1    1931     -6.4
# 2    1932    -12.9
# 3    1933     -1.3
# 4    1933     -1.2
# ..    ...      ...
# 124  2018      2.9
# 125  2018      3.0
# 126  2019      2.3
# 127  2019      2.2
# 128  2020     -3.5
#
# [129 rows x 2 columns]

# %%
# Drop the duplicated year values

gdp_df = gdp_df.drop_duplicates(keep='last', subset=['date'])
gdp_df
# Out:
#      date gdp_rate
# 0    1930     -8.5
# 1    1931     -6.4
# 2    1932    -12.9
# 4    1933     -1.2
# 5    1934     10.8
# ..    ...      ...
# 119  2016      1.7
# 123  2017      2.3
# 125  2018      3.0
# 127  2019      2.2
# 128  2020     -3.5
#
# [91 rows x 2 columns]

# %% [markdown]
# ### Reading xls to obtain Money Stock (M3) in the US

# %%
# Read United States values M3 values from 1958 into a dataframe

m3_data = pd.read_excel('us_m3.xls')
m3_data
# Out:
#    observation_date  MABMM301USA657S_20210414
# 0        1958-01-01                       NaN
# 1        1959-01-01                       NaN
# 2        1960-01-01                  3.744744
# 3        1961-01-01                  6.753574
# 4        1962-01-01                  7.778348
# ..              ...                       ...
# 58       2016-01-01                  6.787281
# 59       2017-01-01                  5.700626
# 60       2018-01-01                  3.848735
# 61       2019-01-01                  5.096518
# 62       2020-01-01                 19.164267
#
# [63 rows x 2 columns]

# %%
# Rename the columns

m3_data.columns = ['date', 'm3_rate']
m3_data
# Out:
#          date    m3_rate
# 0  1958-01-01        NaN
# 1  1959-01-01        NaN
# 2  1960-01-01   3.744744
# 3  1961-01-01   6.753574
# 4  1962-01-01   7.778348
# ..        ...        ...
# 58 2016-01-01   6.787281
# 59 2017-01-01   5.700626
# 60 2018-01-01   3.848735
# 61 2019-01-01   5.096518
# 62 2020-01-01  19.164267
#
# [63 rows x 2 columns]

# %%
#Change date format to year to match the CPI_Inflation table

m3_data['date'] = m3_data['date'].dt.year
m3_data = m3_data.round(decimals=2)
m3_data
# Out:
#     date  m3_rate
# 0   1958      NaN
# 1   1959      NaN
# 2   1960     3.74
# 3   1961     6.75
# 4   1962     7.78
# ..   ...      ...
# 58  2016     6.79
# 59  2017     5.70
# 60  2018     3.85
# 61  2019     5.10
# 62  2020    19.16
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Merge Tables

# %%
new_df = pd.merge(cpi_inflation_df, gdp_df, on='date', how='outer')
new_df
# Out:
#     date dollar_value inflation_rate gdp_rate
# 0   1930        $1.00         -2.34%     -8.5
# 1   1931        $0.91         -8.98%     -6.4
# 2   1932        $0.82         -9.87%    -12.9
# 3   1933        $0.78         -5.11%     -1.2
# 4   1934        $0.80          3.08%     10.8
# ..   ...          ...            ...      ...
# 87  2017       $14.68          2.13%      2.3
# 88  2018       $15.04          2.49%      3.0
# 89  2019       $15.31          1.76%      2.2
# 90  2020       $15.50          1.23%     -3.5
# 91  2021       $16.35         5.48%*      NaN
#
# [92 rows x 4 columns]

# %%
combined_df = pd.merge(new_df, m3_data, on='date', how='outer')
combined_df
# Out:
#     date dollar_value inflation_rate gdp_rate  m3_rate
# 0   1930        $1.00         -2.34%     -8.5      NaN
# 1   1931        $0.91         -8.98%     -6.4      NaN
# 2   1932        $0.82         -9.87%    -12.9      NaN
# 3   1933        $0.78         -5.11%     -1.2      NaN
# 4   1934        $0.80          3.08%     10.8      NaN
# ..   ...          ...            ...      ...      ...
# 87  2017       $14.68          2.13%      2.3     5.70
# 88  2018       $15.04          2.49%      3.0     3.85
# 89  2019       $15.31          1.76%      2.2     5.10
# 90  2020       $15.50          1.23%     -3.5    19.16
# 91  2021       $16.35         5.48%*      NaN      NaN
#
# [92 rows x 5 columns]

# %%
## Drop Nulls
clean_df = combined_df.dropna(how='any')
clean_df
# Out:
#     date dollar_value inflation_rate gdp_rate  m3_rate
# 30  1960        $1.77          1.72%      2.6     3.74
# 31  1961        $1.79          1.01%      2.6     6.75
# 32  1962        $1.81          1.00%      6.1     7.78
# 33  1963        $1.83          1.32%      4.4     8.43
# 34  1964        $1.86          1.31%      5.8     7.83
# ..   ...          ...            ...      ...      ...
# 86  2016       $14.37          1.26%      1.7     6.79
# 87  2017       $14.68          2.13%      2.3     5.70
# 88  2018       $15.04          2.49%      3.0     3.85
# 89  2019       $15.31          1.76%      2.2     5.10
# 90  2020       $15.50          1.23%     -3.5    19.16
#
# [61 rows x 5 columns]

# %%
plt.plot(clean_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1519         try:
# -> 1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-46-abeda15446a1> in <module>
# ----> 1 plt.plot(clean_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# -> 1745             self.add_line(line)
#    1746         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1747         return lines
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1962             line.set_clip_path(self.patch)
#    1963
# -> 1964         self._update_line_limits(line)
#    1965         if not line.get_label():
#    1966             line.set_label('_line%d' % len(self.lines))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1984         Figures out the data limit of the given line, updating self.dataLim.
#    1985         """
# -> 1986         path = line.get_path()
#    1987         if path.vertices.size == 0:
#    1988             return
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1009         """
#    1010         if self._invalidy or self._invalidx:
# -> 1011             self.recache()
#    1012         return self._path
#    1013
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     655             x = self._x
#     656         if always or self._invalidy:
# --> 657             yconv = self.convert_yunits(self._yorig)
#     658             y = _to_unmasked_float_array(yconv).ravel()
#     659         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in convert_yunits(self, y)
#     185         if ax is None or ax.yaxis is None:
#     186             return y
# --> 187         return ax.yaxis.convert_units(y)
#     188
#     189     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
# -> 1522             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1523                                          f'units: {x!r}') from e
#    1524         return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['$1.77', '$1.79', '$1.81', '$1.83', '$1.86', '$1.89', '$1.94',
#        '$2.00', '$2.08', '$2.20', '$2.32', '$2.43', '$2.50', '$2.66',
#        '$2.95', '$3.22', '$3.41', '$3.63', '$3.90', '$4.35', '$4.93',
#        '$5.44', '$5.78', '$5.96', '$6.22', '$6.44', '$6.56', '$6.80',
#        '$7.08', '$7.43', '$7.83', '$8.16', '$8.40', '$8.65', '$8.87',
#        '$9.13', '$9.40', '$9.61', '$9.76', '$9.98', '$10.31', '$10.60',
#        '$10.77', '$11.02', '$11.31', '$11.69', '$12.07', '$12.42',
#        '$12.89', '$12.85', '$13.06', '$13.47', '$13.75', '$13.95',
#        '$14.18', '$14.19', '$14.37', '$14.68', '$15.04', '$15.31',
#        '$15.50'], dtype=object)

# %% [markdown]
# ### Create database connection and load the individual tables into database

# %%
connection_string = "postgres:Bias1981@localhost:5432/economic_indicators"
engine = create_engine(f'postgresql://{connection_string}')

# %%
cpi_inflation_df.to_sql(name='cpi_inflation', con=engine, if_exists='append', index=False)

# %%
gdp_df.to_sql(name='gdp', con=engine, if_exists='append', index=False)

# %%
m3_data.to_sql(name='m3', con=engine, if_exists='append', index=False)

# %%
# Confirm tables exist in database
engine.table_names()
# Out:
# ['cpi_inflation', 'gdp', 'm3']

# %% [markdown]
# ### Query the tables

# %%
pd.read_sql_query('select * from cpi_inflation', con=engine).head()
# Out:
#    date dollar_value inflation_rate
# 0  1930        $1.00         -2.34%
# 1  1931        $0.91         -8.98%
# 2  1932        $0.82         -9.87%
# 3  1933        $0.78         -5.11%
# 4  1934        $0.80          3.08%

# %%
pd.read_sql_query('select * from gdp', con=engine).head()
# Out:
#    date gdp_rate
# 0  1930     -8.5
# 1  1931     -6.4
# 2  1932    -12.9
# 3  1933     -1.2
# 4  1934     10.8

# %%
pd.read_sql_query('select * from m3', con=engine).head()
# Out:
#    date  m3_rate
# 0  1958      NaN
# 1  1959      NaN
# 2  1960     3.74
# 3  1961     6.75
# 4  1962     7.78
